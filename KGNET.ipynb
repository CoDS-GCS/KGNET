# %%
from sparqlEndpoints.openlinkVirtuosoEndpoint import openlinkVirtuosoEndpoint
from sparqlEndpoints.sparqlEndpoint import sparqlEndpoint
sparqlEndpoint1=openlinkVirtuosoEndpoint()
# sparqlEndpoint1=sparqlEndpoint()
type(sparqlEndpoint1)
# Out:
# sparqlEndpoints.openlinkVirtuosoEndpoint.openlinkVirtuosoEndpoint

# %%
# print(sparqlEndpoint1.version)
# sparqlEndpoint1.endpointUrl="http://192.168.79.140:8890/sparql"
query="""prefix ns1: <https://www.forbes.com/> 
                select * where
                {
                        select ?name ?brief ?Logo ?employees_count ?MV ?Market_Value_class  ?Sales ?Profits
                        where
                        {
                        # ?s ns1:has_type ns1:Company.
                        # ?s ns1:has_label ?name.
                        # ?s ns1:has_Country ?cont.
                        # ?s ns1:has_Revenue   ?Sales.
                        # ?s ns1:has_Profits ?Profits.
                        # ?s ns1:has_Assets ?Assets.
                        # ?cont ns1:has_label ?cont_label.
                        # ?s ns1:has_Industry ?indst.
                        # ?s ns1:has_Market_Value ?MV.
                        # ?s ns1:has_Market_Value_class ?Mclass.
                        # ?Mclass ns1:has_label ?Market_Value_class.
                        # ?s ns1:has_Des ?brief.
                        # ?s ns1:has_Logo ?Logo.
                        # ?s ns1:has_employees_count ?employees_count.
                        }
                    }               
                """
ds=sparqlEndpoint1.executeSparqlQuery(query)
ds
# Out:
#                                                    name  \
# 0                                                   ANZ
# 1                                          BHP_Billiton
# 2                                                   CSL
# 3                                     Commonwealth_Bank
# 4                               National_Australia_Bank
# ...                                                 ...
# 1995                                      Grupo_Zuliano
# 1996  Commercial_Bank_For_Investment_&_Development_O...
# 1997  Joint_Stock_Commercial_Bank_for_Foreign_Trade_...
# 1998                                        Vietin_Bank
# 1999                                           Vingroup
#
#                                                   brief  \
# 0       stockbroker, brokerage firm, and bank in Sweden
# 1                    American multinational corporation
# 2                                                   NaN
# 3                         Australian multinational bank
# ...

# %%
sparqlEndpoint1.VirtuosoConn
# Out:
# 'DRIVER=/usr/local/virtuoso-opensource/lib/virtodbc.so;HOST=localhost:1111;UID=dba;PWD=dba'

# %%
sparqlEndpoint1.getVirtuosoGraphsList()
# Out:
# (                                            g
#  0                                      b3sifp
#  1                                     b3sonto
#  2                                      facets
#  3                   http://BritishRoyalFamily
#  4                   http://CIC_DOH2020_1K.ttl
#  ..                                        ...
#  88      urn:spin:nanotation:demo:royal:family
#  89  urn:spin:nanotation:demo:royal:family:lib
#  90                                virtrdf-ifp
#  91                              virtrdf-label
#  92                                virtrdf-url
#
#  [93 rows x 1 columns],
#  '\n            SELECT  DISTINCT ?g \n            WHERE  { GRAPH ?g {?s ?p ?o} } \n            ORDER BY  ?g\n            limit 100\n        ')

# %%
from embeddingServices.similarityMetrics  import cosineSimilarity
cs=cosineSimilarity()

# %%
cs.get([1,2,3],[4,2,1])
# Out:
# 0.6415330278717847

# %%
from embeddingServices.similarityMetrics  import euclideanDistance
ed=euclideanDistance()
ed.get([1,2,3],[4,2,1])
# Out:
# 3.605551275463989

# %%
from embeddingServices.embeddingStore  import faissInMemoryStore
FS=faissInMemoryStore()
FS.dataPath="/KGNet/Forbes2013/"
FS.datasetName="Forbes2013"
FS.addToIndexFlatL2Dic("ComplEx","Forbes2013_Companies_emb_ComplEx_df.pickle")
# FS.addToIndexIVFFlatDic("ComplEx","Forbes2013_Companies_emb_ComplEx_df.pickle")
# Out:
# Faiss IndexFlatL2 added ComplEx for 2000 entity to dataset Forbes2013

# %%
FS.searchTopSimilarEntites_FlatL2D("ComplEx","IBM",cs,10)
# Out:
# {'Walt_Disney': 0.6891060316597433,
#  'Pfizer': 0.6621119220283557,
#  'NVIDIA': 0.6517526216035731,
#  'American_Express': 0.6260220411434371,
#  'ExxonMobil': 0.6242053873394846,
#  'UnitedHealth_Group': 0.6151666752241313,
#  'Amazon.com': 0.6107334177494521,
#  'Mastercard': 0.6021366471742788,
#  'Tencent_Holdings': 0.5867852562826088,
#  'Starbucks': 0.5617025030857308}

# %%
FS.getSimilartyScore("ComplEx","IBM","Intel",cs)
# Out:
# 0.4231482446193695

# %%
from embeddingServices.embeddingStore  import pickleInMemoryStore
PS=pickleInMemoryStore()
PS.dataPath="/KGNet/Forbes2013/"
PS.datasetName="Forbes2013"
PS.add("ComplEx","Forbes2013_Companies_emb_ComplEx_df.pickle")
# Out:
# pickleInMemoryStore added ComplEx for 2000 entities to dataset Forbes2013

# %%
PS.embDic["ComplEx"]
# Out:
#                           entity  \
# 0                           ICBC
# 1        China_Construction_Bank
# 2                 JPMorgan_Chase
# 3             Berkshire_Hathaway
# 4     Agricultural_Bank_of_China
# ...                          ...
# 1995           Sumec_Corporation
# 1996     BioMarin_Pharmaceutical
# 1997       China_Agri-Industries
# 1998        Prudential_Financial
# 1999                      Oracle
#
#                                                     emb name
# 0     [-0.51067215, 0.6362451, 0.501669, 0.059694655...
# 1     [-0.5388376, 0.20518437, 0.27491102, -0.297248...
# 2     [-0.61467737, 0.40265164, 0.34704235, -0.10067...
# 3     [-0.577535, 0.2963267, 0.50234354, 0.46629038,...
# 4     [-0.42650765, 0.41078877, 0.45362198, 0.418147...
# ...                                                 ...  ...
# 1995  [0.10527117, 0.4332026, 0.23970531, 0.2677061,...
# 1996  [-0.29014942, 0.24654923, 0.4886429, 0.723704,...
# ...

# %%
from embeddingServices.KGEmbeddingService import embeddingAsaService
embeddingAsaService.embeddingStores={}
embeddingAsaService.embeddingStores["pickle"]=PS
embeddingAsaService.embeddingStores["faiss"]=FS
embeddingAsaService.serviceName="Forbes2013 Embedding Server"
# forbes2013_ES.initalize("forbes2013",6250,"0.0.0.0",server)

# %%
from embeddingServices.KGEmbeddingService import startHttpServerThread
startHttpServerThread(embeddingAsaService,"forbes2013",6250,"0.0.0.0")
# Out:
# Embedding Service forbes2013 started at http://0.0.0.0:6250
# doPost request Received at Server=Forbes2013 Embedding Server
# path= /getEmbeddingVector  data= {'entity': 'IBM', 'emb_technique': 'ComplEx'}
# 172.17.0.1 - - [22/Dec/2021 16:48:29] "POST /getEmbeddingVector HTTP/1.1" 200 -
# doPost request Received at Server=Forbes2013 Embedding Server
# path= /getEmbeddingVector  data= {'entity': 'IBM', 'emb_technique': 'ComplEx'}
# 172.17.0.1 - - [22/Dec/2021 16:48:47] "POST /getEmbeddingVector HTTP/1.1" 200 -
# 172.17.0.1 - - [22/Dec/2021 17:05:22] code 501, message Unsupported method ('GET')
# 172.17.0.1 - - [22/Dec/2021 17:05:22] "GET / HTTP/1.1" 501 -
# 172.17.0.1 - - [22/Dec/2021 17:05:22] code 501, message Unsupported method ('GET')
# 172.17.0.1 - - [22/Dec/2021 17:05:22] "GET /favicon.ico HTTP/1.1" 501 -

# %%
PS.embDic["ComplEx"][PS.embDic["ComplEx"]["entity"]=="Intel"]
# Out:
#    entity                                                emb name
# 48  Intel  [-0.26864147, 0.5112071, 0.18322445, 0.4357012...

# %%
PS.searchTopSimilarEntites("ComplEx","IBM",ed,20)
# Out:
# {'Aegon': 6.266129493713379,
#  'Xiamen_International_Trade_Group': 6.201050758361816,
#  'Fangda_Carbon_New_Material': 6.157619476318359,
#  'Companhia_Brasileira_de_Distribuicao': 6.035938739776611,
#  'Fresnillo': 6.000824451446533,
#  'Chinatrust_Financial': 5.996463298797607,
#  'Telecom_Argentina': 5.9874677658081055,
#  'Generali_Group': 5.9757208824157715,
#  'HCL_Technologies': 5.966862678527832,
#  'Harbin_Bank': 5.875460147857666,
#  'Hana_Financial_Group': 5.866859436035156,
#  'Korean_Air': 5.859152793884277,
#  'Harris': 5.856596946716309,
#  'JC_Penney': 5.817905426025391,
#  'SQM': 5.803502559661865,
#  'Thomas_Cook_Group': 5.80059289932251,
#  'Philips': 5.781260967254639,
#  'Husky_Energy': 5.771347522735596,
#  'Haseko': 5.756497383117676,
#  'Huaneng_Power_International': 5.739973068237305,
#  'Aon': 5.7327561378479}

# %%
PS.getSimilarScore("ComplEx","IBM","Intel",cs)
# Out:
# 0.4231482446193695

# %%
from embeddingServices.generateKGEmbeddings import RDF2Vec
rdf2vec=RDF2Vec(50)
# Out:
# /root/anaconda3/envs/ampligraph/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /root/anaconda3/envs/ampligraph/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /root/anaconda3/envs/ampligraph/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
print(sparqlEndpoint1.version)
# sparqlEndpoint1.endpointUrl="http://192.168.79.140:8890/sparql"
query="""prefix ns1: <https://www.forbes.com/> 
            select ?s as ?subject ?p as ?predicate ?o as ?object
            where
            {
            # ?s ns1:has_type ns1:Company.
            # ?s ?p ?o
            }           
       """
ds=sparqlEndpoint1.executeSparqlQuery(query)
ds
# Out:
# vos 7.5.2
#                                                 subject  \
# 0                     https://www.forbes.com/Company/3M
# 1                https://www.forbes.com/Company/77_Bank
# 2                    https://www.forbes.com/Company/ABB
# 3                    https://www.forbes.com/Company/AES
# 4             https://www.forbes.com/Company/AGL_Energy
# ...                                                 ...
# 9995              https://www.forbes.com/Company/Kajima
# 9996  https://www.forbes.com/Company/Kansai_Electric...
# 9997  https://www.forbes.com/Company/Kansas_City_Sou...
# 9998        https://www.forbes.com/Company/Kasikornbank
# 9999  https://www.forbes.com/Company/Kawasaki_Heavy_...
#
#                                        predicate  object
# 0              https://www.forbes.com/has_Assets  38.575
# 1              https://www.forbes.com/has_Assets  75.939
# 2              https://www.forbes.com/has_Assets   43.57
# ...

# %%
titles=ds[ds["predicate"]=="https://www.forbes.com/has_label"]["object"].tolist()

# %%
rdf2vec.kgPath="/KGNet/Forbes2013/Forbes2013_enriched.ttl"
rdf2vec.entities=titles
rdf2vec.generateEmbeddings()
# Out:
#                    entity         0         1         2         3         4  \
# 0                      3M  0.014147 -0.006893 -0.011511 -0.007707  0.008473
# 1                 77_Bank -0.017761 -0.003210  0.013512  0.016680 -0.017987
# 2                     ABB -0.008947 -0.000281  0.008835 -0.019963  0.007590
# 3                     AES -0.001019 -0.013711  0.007796  0.003814 -0.003062
# 4              AGL_Energy  0.006571  0.018132  0.013492 -0.019987 -0.003039
# ..                    ...       ...       ...       ...       ...       ...
# 545              Inchcape -0.009408 -0.014930  0.007827  0.008716 -0.000235
# 546           Indian_Bank -0.012883  0.001463 -0.015987  0.015124 -0.019312
# 547            Indian_Oil  0.008148 -0.013725 -0.018303  0.017927 -0.011792
# 548  Indian_Overseas_Bank  0.006152 -0.003169 -0.002393 -0.011696 -0.011535
# 549               Inditex -0.001072  0.000473  0.010207  0.018019 -0.018606
#
# ...

# %%
import numpy as np
X_train=np.array(ds)
X_train
# Out:
# array([['https://www.forbes.com/Company/3M',
#         'https://www.forbes.com/has_Assets', '38.575'],
#        ['https://www.forbes.com/Company/77_Bank',
#         'https://www.forbes.com/has_Assets', '75.939'],
#        ['https://www.forbes.com/Company/ABB',
#         'https://www.forbes.com/has_Assets', '43.57'],
#        ...,
#        ['https://www.forbes.com/Company/Kansas_City_Southern',
#         'https://www.forbes.com/has_employees_count', '6359.0'],
#        ['https://www.forbes.com/Company/Kasikornbank',
#         'https://www.forbes.com/has_employees_count', '8167.0'],
#        ['https://www.forbes.com/Company/Kawasaki_Heavy_Industries',
#         'https://www.forbes.com/has_employees_count', '0.0']],
#       dtype=object)

# %%
from embeddingServices.generateKGEmbeddings import ComplEx
complEx=ComplEx(ds,10)
complEx.entities=titles
ds=complEx.generateEmbeddings()
# Out:
# Average ComplEx Loss:   0.293871: 100%|██████| 50/50 [00:12<00:00,  4.09epoch/s]

# %%
from embeddingServices.generateKGEmbeddings import ConvKB
convKB=ConvKB(ds,10)
convKB.entities=titles
ds=convKB.generateEmbeddings()
# Out:
# Average ConvKB Loss:   0.043628: 100%|███████| 10/10 [00:11<00:00,  1.13s/epoch]

# %%
print(sparqlEndpoint1.version)
# sparqlEndpoint1.endpointUrl="http://192.168.79.140:8890/sparql"
query="""prefix ns1: <https://www.forbes.com/> 
            select ?name ?Market_Value_class
            where
            {
            # ?s ns1:has_type ns1:Company.
            # ?s ns1:has_label ?name.
            # ?s ns1:has_Market_Value_class ?Mclass.
            # ?Mclass ns1:has_label ?Market_Value_class.
            }           
       """
ds_comp=sparqlEndpoint1.executeSparqlQuery(query)
# Out:
# vos 7.5.2

# %%
ds["MV"]=None
for idx,row in ds.iterrows():
#     print(row["entity"])
    MV=list(ds_comp[ds_comp["name"]==row["entity"]]["Market_Value_class"].values)[0]
#     print(MV)
    uidx=ds[ds["entity"]==row["entity"]].index
    ds.at[uidx, 'MV'] = MV
#     df.xs('C')['x']=10
ds
# Out:
#                    entity         0         1         2         3         4  \
# 0                      3M  0.207353  0.188759  0.358751  0.793835  0.619073
# 1                 77_Bank -0.063410  0.614915 -0.535549  0.413235  0.596510
# 2                     ABB  0.262549  0.504409  0.340893  0.481886  0.038056
# 3                     AES  0.410054  0.424595 -0.868480  0.811308  0.459593
# 4              AGL_Energy -0.437802 -0.813161 -0.283336  0.323850  0.190712
# ..                    ...       ...       ...       ...       ...       ...
# 545              Inchcape -0.118715 -0.744185 -0.421754  0.618992 -0.122740
# 546           Indian_Bank  0.547595 -0.406598 -0.472076  0.372820  0.609757
# 547            Indian_Oil  0.722852  0.140749  0.113279 -0.516980  0.210382
# 548  Indian_Overseas_Bank -0.018392 -0.149626 -0.275888  0.619883  0.658167
# 549               Inditex -0.197869  0.600609  0.873816  0.719412  0.500625
#
# ...

# %%
ds_rf=ds.drop(["entity"],axis=1)

# %%
from classificationModels.classificationModel  import RandomForest
rf=RandomForest(ds_rf,"MV",0.2)
rf.getConfusionMatrix()
# Out:
# (array([[11,  1, 12],
#         [ 0, 15,  9],
#         [ 9,  8, 45]]),
#  0.6454545454545455)

# %%
ds["MV"].astype('category').cat.codes.unique().tolist()
# Out:
# [0, 1, 2]

# %%
from cognitiveQueryRewriter.queryRewriter import queryRewriter
qr=queryRewriter()
dict={'??company':"'IBM'",'??top':"'10'",'??emb_tech':"'ComplEx'",'??limit':'10'}
# q=qr.getOptimizedQuery("forbes2013",dict)
qr.getOptimizedQueryFaiss("forbes2013",dict)
# Out:
# "prefix ns1: <https://www.forbes.com/> \n                        select * where\n                        {\n                            select bif:lower(?name) as ?name ?brief ?Logo ?employees_count ?MV ?Market_Value_class  ?Sales ?Profits\n                            xsd:Float(bif:get_keyword(bif:lower(?name),?top_comp,0)) as ?Score\n                             where\n                            {\n                                ?s ns1:has_type ns1:Company.\n                                ?s ns1:has_label ?name.\n                                ?s ns1:has_Country ?cont.\n                                ?s ns1:has_Revenue   ?Sales.\n                                ?s ns1:has_Profits ?Profits.\n                                ?s ns1:has_Assets ?Assets.\n                                ?cont ns1:has_label ?cont_label.\n                                ?s ns1:has_Industry ?indst.\n                                ?s ns1:has_Market_Value ?MV.\n                                ?s ns1:has_
# ...

# %%
sparqlEndpoint1.executeSparqlQuery(q)
# Out:
#                  name                                              brief  \
# 0                 ibm  American multinational technology and consulti...
# 1         walt_disney  American diversified multinational mass media ...
# 2              pfizer  American multinational pharmaceutical corporation
# 3              nvidia          American multinational technology company
# 4    american_express  American multinational financial services corp...
# 5          exxonmobil     American multinational oil and gas corporation
# 6  unitedhealth_group                     for profit health care company
# 7          amazon.com  American electronic commerce and cloud computi...
# 8          mastercard  American multinational financial services corp...
# 9         merck_&_co.  American pharmaceutical company and former sub...
#
#                                                 Logo employees_count       MV  \
# 0  https://upload.wikimedia.org/wikipedia/commons...        352600.0  132.316
# ...
